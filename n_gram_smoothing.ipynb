# %% [markdown]
# <a href="https://colab.research.google.com/github/sathwikakonduru/NLP_LAB/blob/main/n_gram_smoothing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.lm import Laplace
from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt_tab')
nltk.download('punkt')

text = [word_tokenize("I love NLP I love AI".lower())]
train, vocab = padded_everygram_pipeline(2, text)
lm = Laplace(2); lm.fit(train, vocab)

print(lm.score("ai", ["love"]))
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# 0.2222222222222222
