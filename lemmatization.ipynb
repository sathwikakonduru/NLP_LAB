# %% [markdown]
# <a href="https://colab.research.google.com/github/sathwikakonduru/NLP_LAB/blob/main/lemmatization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Lemmatization in Python (NLP)
from nltk.stem import WordNetLemmatizer
from nltk import download
download('wordnet', quiet=True)

lem = WordNetLemmatizer()
words = ["running", "better", "cars"]
print([lem.lemmatize(w, pos='v') for w in words])  # Output: ['run', 'better', 'cars']
# Out:
# ['run', 'better', 'cars']
